# %%
#gitting image using web get
# !wget  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s'
# Out:
# --2024-06-04 16:59:03--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 142.251.2.138, 142.251.2.102, 142.251.2.101, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|142.251.2.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6147 (6.0K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s’
#
# images?q=tbn:ANd9Gc 100%[===================>]   6.00K  --.-KB/s    in 0s
#
# 2024-06-04 16:59:03 (48.3 MB/s) - ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s’ saved [6147/6147]

# %% [markdown]
# **Libraries that can be used for image processing**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
#importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (183, 275, 3)

# %%
print(img)
# Out:
# [[[135 182  18]
#   [137 182  17]
#   [142 186  15]
#   ...
#   [130 149   0]
#   [129 149   0]
#   [129 149   0]]
#
#  [[127 172   7]
#   [126 172   4]
#   [130 172   2]
#   ...
#   [132 151   0]
#   [131 151   0]
#   [131 151   0]]
#
#  [[129 173   2]
#   [126 168   0]
#   [121 164   0]
#   ...
#   [134 153   0]
#   [134 153   2]
#   [134 153   2]]
#
#  ...
#
#  [[ 69  58  28]
#   [ 62  53  20]
#   [ 54  43  11]
#   ...
#   [127 104  37]
#   [128 104  34]
#   [128 104  34]]
#
#  [[ 67  58  27]
#   [ 60  54  20]
#   [ 56  47  14]
#   ...
#   [128 105  38]
#   [129 105  35]
#   [129 105  35]]
#
#  [[ 63  57  25]
#   [ 60  56  21]
#   [ 59  53  19]
#   ...
#   [128 105  38]
#   [129 105  35]
#   [130 106  36]]]

# %%
#displaying the image from numpy array

img_plot =plt.imshow(img)
plt.show()

# %% [markdown]
# **Resizing the image using pillow library**

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized =img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
#displaying the image from numpy array
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot =plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# ***Converting RGB images to Grayscale image using OpenCV ***

# %%
#importing OpenCV library
import cv2

# %%
img =cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image )
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (183, 275)

# %% [markdown]
# cv2.imshow() will display the image.but this will not be allowed in google colab
#
# ***from google.colab.patches import cv2_imshow***

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
#saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
